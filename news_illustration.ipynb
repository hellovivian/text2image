# %%
subjects = ["cyberpunk", "holographic", "glitch", "vaporwave"]
styles = ["Im"]

# %%
from itertools import product

for subject, style in zip(subjects, styles):

    # !python generate.py -i 300 -p f"{subject} in the style of {style}" -o f"text2image-ui/static/images2probe/{subject}_{style}" -s 64 64 -sd 64
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['office scene in the motion blur style ', ' office scene in the Gaussian blur style']
# Using seed: 64
# i: 0, loss: 1.7779, losses: 0.897499, 0.880404
# i: 1, loss: 1.82169, losses: 0.918127, 0.90356
# i: 2, loss: 1.77971, losses: 0.898403, 0.881311
# i: 3, loss: 1.76923, losses: 0.892444, 0.876784
# i: 4, loss: 1.75306, losses: 0.883046, 0.870018
# i: 5, loss: 1.75969, losses: 0.885363, 0.874324
# i: 6, loss: 1.74624, losses: 0.878049, 0.86819
# i: 7, loss: 1.72227, losses: 0.864249, 0.858024
# i: 8, loss: 1.71424, losses: 0.860574, 0.853661
# i: 9, loss: 1.69963, losses: 0.851633, 0.847993
# i: 10, loss: 1.72862, losses: 0.868627, 0.85999
# ...

# %%
# !python generate.py -i 300 -se 1 -p "light in a dark room" -s 256 256  -zvid -sd 64
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['light in a dark room']
# Using seed: 64
# i: 0, loss: 0.875065, losses: 0.875065
# i: 1, loss: 0.870445, losses: 0.870445
# i: 2, loss: 0.88072, losses: 0.88072
# i: 3, loss: 0.874117, losses: 0.874117
# i: 4, loss: 0.864984, losses: 0.864984
# i: 5, loss: 0.866995, losses: 0.866995
# i: 6, loss: 0.862277, losses: 0.862277
# i: 7, loss: 0.85587, losses: 0.85587
# i: 8, loss: 0.854347, losses: 0.854347
# i: 9, loss: 0.849277, losses: 0.849277
# i: 10, loss: 0.84461, losses: 0.84461
# i: 11, loss: 0.848833, losses: 0.848833
# i: 12, loss: 0.848234, losses: 0.848234
# i: 13, loss: 0.840091, losses: 0.840091
# i: 14, loss: 0.837573, losses: 0.837573
# ...

# %%
# !python generate.py -i 300 -se 1 -p "light in a dark room" -s 256 256  -zvid -sd 64
