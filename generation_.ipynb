# %%
art_movements = ["Mexican Muralism", "Feminist Art", "Harlem Renaissance", "Regionalism"]
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['hi']
# Using seed: 12934155378318993518
# i: 0, loss: 0.898952, losses: 0.898952
# i: 50, loss: 0.858692, losses: 0.858692
# i: 100, loss: 0.835238, losses: 0.835238
# 100it [00:11,  9.03it/s]

# %%
subjects = {"Mexican Muralism":["Latin America", "indigenous people", "Tenochtitlan",
                                "sculpture", "Mexica people", "zapatistas",
                               "land", "flowers", "workers", "peasants", "Socialism",
                               "Communism", "Revolution", "conflict", "war", "community"
                               "the Nation state", "identity", "social realism", "Mexican identity"],
           "Feminist art":["a woman", "a man", "a person", "a body", "a phallus", "a yoni",
                           "a face", "clothes", "a portrait", "a costume", "the gaze", 
                           "identity", "social dynamics", "empowerment", "performativity",
                           "language", "biology", "gender", "the patriarchy", "the self"
                          ],
           "Harlem Renaissance":["Black people", "a Black person", "The Great Migration", "a Pharaoh", 
                                 "Egypt", "an African mask", "Africa", "a city", "Harlem", "people dancing",
                                 "ancestry", "societal roles","jazz","Pan-Africanism", "the South",
                                 "the North", "class", "identity","the Talented Tenth", "racism"
                    ],
           "Regionalism":["farm", "farmer", "cowboy", "roads", "an American landscape",
                         "horses", "factory", "town", "wagon", "car", "Industrialism",
                         "agriculture", "Populism", "Manifest Destiny", "Conservatism",
                         "culture", "identity", "American identity", "nationalism", "rurality"]}

# %%
s = 'a'
f'{s}'.format()
subjects[art_movement]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_103/1368280180.py in <module>
#       1 s = 'a'
#       2 f'{s}'.format()
# ----> 3 subjects[art_movement]
#
# TypeError: unhashable type: 'list'

# %%
from itertools import product
art_movement = "Harlem Renaissance"
art_movement_dupe = ["Harlem Renaissance"] * len(subjects[art_movement])
prompts = list(zip(subjects[art_movement],art_movement_dupe))

for prompt in prompts:
    subject, style = prompt[0], prompt[1]
    # !python generate.py -i 300 -p "{subject} in the style of {style}" -s 256 256 -o "outputs/{subject} in the style of {style}_64.jpg" -sd 64
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['Black people in the style of Harlem Renaissance']
# Using seed: 64
# i: 0, loss: 0.9274, losses: 0.9274
# i: 50, loss: 0.894295, losses: 0.894295
# i: 100, loss: 0.911458, losses: 0.911458
# i: 150, loss: 0.888501, losses: 0.888501
# i: 200, loss: 0.90157, losses: 0.90157
# i: 250, loss: 0.903851, losses: 0.903851
# i: 300, loss: 0.915995, losses: 0.915995
# 300it [00:30,  9.70it/s]
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# ...

# %%
from itertools import product
art_movement = "Feminist art"
art_movement_dupe = ["Feminist art"] * len(subjects[art_movement])
prompts = list(zip(subjects[art_movement],art_movement_dupe))

for prompt in prompts:
    subject, style = prompt[0], prompt[1]
    # !python generate.py -i 300 -p "{subject} in the style of {style}" -s 256 256 -o "outputs/{subject} in the style of {style}_64.jpg" -sd 64
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['a woman in the style of Feminist art']
# Using seed: 64
# i: 0, loss: 0.904225, losses: 0.904225
# i: 50, loss: 0.866946, losses: 0.866946
# i: 100, loss: 0.861308, losses: 0.861308
# i: 150, loss: 0.839435, losses: 0.839435
# i: 200, loss: 0.848324, losses: 0.848324
# i: 250, loss: 0.846892, losses: 0.846892
# i: 300, loss: 0.830351, losses: 0.830351
# 300it [00:30,  9.71it/s]
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# ...

# %%
from itertools import product
art_movement = "Mexican Muralism"
art_movement_dupe = ["Mexican Muralism"] * len(subjects[art_movement])
prompts = list(zip(subjects[art_movement],art_movement_dupe))

for prompt in prompts:
    subject, style = prompt[0], prompt[1]
    # !python generate.py -i 300 -p "{subject} in the style of {style}" -s 256 256 -o "outputs/{subject} in the style of {style}_64.jpg" -sd 64
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['Latin America in the style of Mexican Muralism']
# Using seed: 64
# i: 0, loss: 0.963102, losses: 0.963102
# i: 50, loss: 0.913086, losses: 0.913086
# i: 100, loss: 0.932969, losses: 0.932969
# i: 150, loss: 0.917478, losses: 0.917478
# i: 200, loss: 0.928432, losses: 0.928432
# i: 250, loss: 0.92305, losses: 0.92305
# i: 300, loss: 0.903294, losses: 0.903294
# 300it [00:30,  9.69it/s]
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# ...

# %%
from itertools import product
art_movement = "Regionalism"
art_movement_dupe = ["Regionalism"] * len(subjects[art_movement])
prompts = list(zip(subjects[art_movement],art_movement_dupe))

for prompt in prompts:
    subject, style = prompt[0], prompt[1]
    # !python generate.py -i 300 -p "{subject} in the style of {style}" -s 256 256 -o "outputs/{subject} in the style of {style}_64.jpg" -sd 64
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['farm in the style of Regionalism']
# Using seed: 64
# i: 0, loss: 0.900199, losses: 0.900199
# i: 50, loss: 0.823849, losses: 0.823849
# i: 100, loss: 0.767481, losses: 0.767481
# i: 150, loss: 0.786354, losses: 0.786354
# i: 200, loss: 0.752163, losses: 0.752163
# i: 250, loss: 0.745296, losses: 0.745296
# i: 300, loss: 0.720781, losses: 0.720781
# 300it [00:30,  9.72it/s]
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# ...

# %%
from itertools import product
art_movement = "Regionalism"
art_movement_dupe = ["Regionalism"] * len(subjects[art_movement])
prompts = list(zip(subjects[art_movement],art_movement_dupe))

for prompt in prompts:
    subject, style = prompt[0], prompt[1]
    # !python generate.py -i 300 -p "{subject} in the style of {style}" -s 256 256 -o "outputs/{subject} in the style of {style}_16.jpg" -sd 16
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['farm in the style of Regionalism']
# Using seed: 16
# i: 0, loss: 0.924549, losses: 0.924549
# i: 50, loss: 0.872005, losses: 0.872005
# i: 100, loss: 0.850293, losses: 0.850293
# i: 150, loss: 0.852847, losses: 0.852847
# i: 200, loss: 0.855962, losses: 0.855962
# i: 250, loss: 0.850873, losses: 0.850873
# i: 300, loss: 0.825831, losses: 0.825831
# 300it [00:30,  9.73it/s]
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# ...

# %%
from itertools import product
art_movement = "Mexican Muralism"
art_movement_dupe = ["Mexican Muralism"] * len(subjects[art_movement])
prompts = list(zip(subjects[art_movement],art_movement_dupe))

for prompt in prompts:
    subject, style = prompt[0], prompt[1]
    # !python generate.py -i 300 -p "{subject} in the style of {style}" -s 256 256 -o "outputs/{subject} in the style of {style}_16.jpg" -sd 16
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['Latin America in the style of Mexican Muralism']
# Using seed: 16
# i: 0, loss: 1.00006, losses: 1.00006
# i: 50, loss: 0.940739, losses: 0.940739
# i: 100, loss: 0.921495, losses: 0.921495
# i: 150, loss: 0.917515, losses: 0.917515
# i: 200, loss: 0.923838, losses: 0.923838
# i: 250, loss: 0.919183, losses: 0.919183
# i: 300, loss: 0.921247, losses: 0.921247
# 300it [00:30,  9.75it/s]
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# ...

# %%
from itertools import product
art_movement = "Feminist art"
art_movement_dupe = ["Feminist art"] * len(subjects[art_movement])
prompts = list(zip(subjects[art_movement],art_movement_dupe))

for prompt in prompts:
    subject, style = prompt[0], prompt[1]
    # !python generate.py -i 300 -p "{subject} in the style of {style}" -s 256 256 -o "outputs/{subject} in the style of {style}_16.jpg" -sd 16
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['a woman in the style of Feminist art']
# Using seed: 16
# i: 0, loss: 0.923836, losses: 0.923836
# i: 50, loss: 0.85613, losses: 0.85613
# i: 100, loss: 0.842185, losses: 0.842185
# i: 150, loss: 0.800462, losses: 0.800462
# i: 200, loss: 0.801543, losses: 0.801543
# i: 250, loss: 0.777095, losses: 0.777095
# i: 300, loss: 0.802787, losses: 0.802787
# 300it [00:31,  9.54it/s]
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# ...

# %%
from itertools import product
art_movement = "Harlem Renaissance"
art_movement_dupe = ["Harlem Renaissance"] * len(subjects[art_movement])
prompts = list(zip(subjects[art_movement],art_movement_dupe))

for prompt in prompts:
    subject, style = prompt[0], prompt[1]
    # !python generate.py -i 300 -p "{subject} in the style of {style}" -s 256 256 -o "outputs/{subject} in the style of {style}_16.jpg" -sd 16

# %%
for prompt in prompts:
    subject, style = prompt[0], prompt[1]
    # !python generate.py -i 300 -p "{subject} in the style of {style}" -s 256 256 -o "outputs/{subject} in the style of {style}_16.jpg" -sd 16
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['Black people in the style of Harlem Renaissance']
# Using seed: 16
# i: 0, loss: 0.954993, losses: 0.954993
# i: 50, loss: 0.919401, losses: 0.919401
# i: 100, loss: 0.893405, losses: 0.893405
# i: 150, loss: 0.895852, losses: 0.895852
# i: 200, loss: 0.898727, losses: 0.898727
# i: 250, loss: 0.886568, losses: 0.886568
# i: 300, loss: 0.799302, losses: 0.799302
# 300it [00:31,  9.61it/s]
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# ...

# %%
zip(art_movement, subjects[art_movement]) for art_movement in artmovements
f'{subject} in the style of {style}'

# %%
# !python generate.py -i 50 -p "3D render of a house in the style of Futurism" -s 507 338 -o "hi.jpg" -sd 16 -ii "house.jpg"
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth
# VQLPIPSWithDiscriminator running with hinge loss.
# Restored from checkpoints/vqgan_imagenet_f16_16384.ckpt
# Using device: cuda:0
# Optimising using: Adam
# Using text prompts: ['3D render of a house in the style of Futurism']
# Using initial image: house.jpg
# Using seed: 16
# i: 0, loss: 0.8119, losses: 0.8119
# i: 50, loss: 0.723586, losses: 0.723586
# 50it [00:09,  5.19it/s]
